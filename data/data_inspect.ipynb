# %%
import pandas as pd
import os

# %%
train_data_path = os.path.join('processed_train_data.pkl')
train_data = pd.read_pickle(train_data_path)

test_data_path = os.path.join('processed_test_data.pkl')
test_data = pd.read_pickle(test_data_path)

# %%
train_data.head()
# Out:
#    Age upon Intake  Breed         Color     Outcome Type  \
# 0          417.420     10   White/Liver  Return to Owner
# 1           47.795     55   Sable/White  Return to Owner
# 2          104.355  16046  Orange Tabby         Transfer
# 3          104.355   5654     Chocolate  Return to Owner
# 4          313.065    100         Black  Return to Owner
#
#    Intake Condition_Aged  Intake Condition_Agonal  Intake Condition_Behavior  \
# 0                  False                    False                      False
# 1                  False                    False                      False
# 2                  False                    False                      False
# 3                  False                    False                      False
# 4                  False                    False                      False
#
#    Intake Condition_Congenital  Intake Condition_Feral  \
# 0                        False                   False
# ...

# %%
test_data.head()
# Out:
#    Id  Age upon Intake  Breed        Color  Intake Condition_Aged  \
# 0   1          104.355    109     Tricolor                  False
# 1   2            4.000   6441       Calico                  False
# 2   3          208.710      1     Tan/Gray                  False
# 3   4           21.725    503  Brown/White                  False
# 4   5          104.355   6441  Black/White                  False
#
#    Intake Condition_Agonal  Intake Condition_Behavior  Intake Condition_Feral  \
# 0                    False                      False                   False
# 1                    False                      False                   False
# 2                    False                      False                   False
# 3                    False                      False                   False
# 4                    False                      False                   False
#
#    Intake Condition_Injured  Intake Condition_Med Attn  ...  \
# ...

# %%
x = set(train_data.columns)
y = set(test_data.columns)

z = x.difference(y)
print(x)
print(y)
print(z)
# Out:
# {'Age upon Intake', 'Intake Type_Euthanasia Request', 'Breed', 'Intake Condition_Med Urgent', 'Outcome Type', 'Intake Condition_Unknown', 'Intake Condition_Agonal', 'Sex upon Intake_Intact Female', 'Intake Condition_Other', 'Intake Type_Owner Surrender', 'Sex upon Intake_Intact Male', 'Animal Type_Dog', 'Intake Condition_Med Attn', 'Intake Condition_Aged', 'Intake Condition_Sick', 'Intake Condition_Injured', 'Intake Type_Stray', 'Sex upon Intake_Unknown', 'Color', 'Intake Condition_Medical', 'Intake Condition_Space', 'Intake Condition_Behavior', 'Intake Condition_Nursing', 'Intake Condition_Normal', 'Intake Condition_Feral', 'Intake Condition_Neonatal', 'Sex upon Intake_Spayed Female', 'Intake Condition_Congenital', 'Intake Type_Public Assist', 'Intake Year', 'Intake Type_Wildlife', 'Intake Type_Abandoned', 'Intake Condition_Parvo', 'Intake Month', 'Intake Condition_Pregnant', 'Animal Type_Cat', 'Sex upon Intake_Neutered Male', 'Intake Condition_Neurologic'}
# ...

# %% [markdown]
# **'Intake Condition_Congenital'**, 'Intake Type_Wildlife', 'Intake Condition_Neurologic'
#
#                                    'Intake Condition_Panleuk'
# {'Intake Condition_Congenital', 'Intake Type_Wildlife', 'Outcome Type', 'Intake Condition_Neurologic'}

# %%
train_data.head()
# Out:
#    Age upon Intake  Breed         Color     Outcome Type  \
# 0          417.420     10   White/Liver  Return to Owner
# 1           47.795     55   Sable/White  Return to Owner
# 2          104.355  16046  Orange Tabby         Transfer
# 3          104.355   5654     Chocolate  Return to Owner
# 4          313.065    100         Black  Return to Owner
#
#    Intake Condition_Aged  Intake Condition_Agonal  Intake Condition_Behavior  \
# 0                  False                    False                      False
# 1                  False                    False                      False
# 2                  False                    False                      False
# 3                  False                    False                      False
# 4                  False                    False                      False
#
#    Intake Condition_Congenital  Intake Condition_Feral  \
# 0                        False                   False
# ...
